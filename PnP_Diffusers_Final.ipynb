# %% [markdown]
# # Plug-and-Play Diffusion Features — Colab Inference Notebook
#
# This notebook is prepared for a GitHub repository and can be opened directly in Google Colab.
#
# **What it does**
# - Clones and installs the PnP Diffusers implementation.
# - Lets you upload and select custom input images.
# - Applies compatibility patches needed for the current Colab/Diffusers environment.
# - Runs preprocessing and editing through the official PnP workflow.
# - Displays generated outputs for success and failure-case analysis.
#
# **Recommended runtime:** Google Colab with GPU enabled.
#
# **How to use**
# 1. Open the notebook in Colab.
# 2. Run the cells from top to bottom.
# 3. Upload your test images in the upload cell.
# 4. Choose the desired experiment case.
# 5. Run preprocessing, editing, and output-display cells.
#
# Some model downloads may require Hugging Face access depending on the selected Stable Diffusion checkpoint.

# %%
# Cell 1 — clone repo and install dependencies
# %cd /content
import os

if not os.path.exists("/content/pnp-diffusers"):
    # !git clone https://github.com/MichalGeyer/pnp-diffusers.git

# %cd /content/pnp-diffusers

# !pip install -q -U pip setuptools wheel
# !pip install -q -r requirements.txt
# !pip install -q ipywidgets matplotlib pillow pyyaml
